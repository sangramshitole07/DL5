# %%
#5. Implement the Continuous Bag of Words (CBOW) Model. Stages can be:
#a. Data preparation
#b. Generate training data
#c. Train model
#d. Output
# a. Data preparation
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Lambda
import tensorflow.keras.backend as K
import random

# Example corpus (small for simplicity, use a larger one for better results)
corpus = [
    "the quick brown fox jumped over the lazy dog",
    "the dog barked at the fox",
    "the fox is quick and the dog is lazy",
    "the quick dog jumped over the lazy fox"
]

# Tokenize the corpus
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
word2idx = tokenizer.word_index
idx2word = {v: k for k, v in word2idx.items()}
vocab_size = len(word2idx) + 1  # Add 1 for padding (if needed)
print(f'Vocabulary Size: {vocab_size}')

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(corpus)

# b. Generate training data
# Context window size: 2 words before and after the target word
window_size = 2

def generate_context_target_pairs(sequences, window_size):
    context_target_pairs = []
    for sequence in sequences:
        for i, word in enumerate(sequence):
            # Define the context window range
            start = max(0, i - window_size)
            end = min(len(sequence), i + window_size + 1)
            context = [sequence[j] for j in range(start, end) if j != i]
            target = word
            if len(context) == window_size * 2:
                context_target_pairs.append((context, target))
    return context_target_pairs

# Generate the training data (context and target pairs)
pairs = generate_context_target_pairs(sequences, window_size)

# Split context and target words
contexts, targets = zip(*pairs)
contexts = np.array(contexts)
targets = np.array(targets)

# One-hot encode the target words
targets = to_categorical(targets, num_classes=vocab_size)

# c. Train the model

# Define CBOW Model
embedding_dim = 100

model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=window_size * 2))
model.add(Lambda(lambda x: K.mean(x, axis=1)))  # Average embeddings for context words
model.add(Dense(vocab_size, activation='softmax'))  # Output softmax over vocabulary

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy')

# Train the model
model.fit(contexts, targets, epochs=100, verbose=1)

# d. Output (Predict target word from context)
# Predict the target word for a given context

def predict_target(context_words):
    # Convert words to their respective indices
    context_indices = [word2idx[word] for word in context_words]
    context_indices = np.array(context_indices).reshape(1, window_size * 2)
    
    # Predict the target word's index
    predicted_idx = np.argmax(model.predict(context_indices), axis=1)[0]
    
    # Convert index back to word
    return idx2word[predicted_idx]

# Example: Predict the target word from the context ['quick', 'brown', 'jumped', 'over']
context_words = ['quick', 'brown', 'jumped', 'over']
predicted_word = predict_target(context_words)
print(f"Context: {context_words} -> Predicted Target Word: '{predicted_word}'")
# Out:
# Vocabulary Size: 13
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - loss: 2.5600
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.5544
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.5488
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5432
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.5376
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.5320
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.5264
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5208
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5152
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.5095
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5039
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4982
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.4925
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.4867
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4809
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4751
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.4692
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4633
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.4573
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.4513
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.4453
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.4391
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4329
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.4267
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4204
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.4140
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.4075
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4010
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.3944
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3877
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3809
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.3741
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.3671
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3601
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3530
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.3458
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.3386
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3312
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.3238
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3162
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.3086
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.3009
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.2931
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.2852
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2772
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.2691
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.2609
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2527
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2443
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.2359
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.2273
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.2187
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2100
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.2012
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1924
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1834
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.1744
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1652
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1560
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1468
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.1374
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1280
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1185
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.1089
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.0992
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 2.0895
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.0797
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.0699
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0600
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.0500
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.0400
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0299
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.0197
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0095
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9992
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.9889
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.9786
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9681
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.9577
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9472
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9366
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9261
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.9154
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9048
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.8941
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8833
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.8726
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8618
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.8510
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.8401
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8292
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8183
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.8074
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.7965
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.7855
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7745
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.7635
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7525
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.7414
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.7304
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Context: ['quick', 'brown', 'jumped', 'over'] -> Predicted Target Word: 'the'
